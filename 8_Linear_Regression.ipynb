# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhrupad-05/Intro-to-Machine-Learning/blob/main/8_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv('placement (1).csv')
df.head(7)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57
# 5  7.89     2.99
# 6  6.73     2.60

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
plt.show()

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57
# 85   4.79
# 10   5.32
# 54   6.86
# 115  8.35
# 35   6.87
# 12   8.94
# 92   7.90
# 13   6.93
# 126  5.91
# 174  7.32
# 2    7.82
# 44   5.09
# 3    7.42
# 113  6.94
# 14   7.73
# 23   6.19
# 25   7.28
# 6    6.73
# 134  7.20
# 165  8.21
# 173  6.75
# 45   7.87
# 65   7.60
# 48   8.63
# 122  5.12
# 178  8.15
# 64   7.36
# 9    8.31
# 57   6.60
# 78   6.59
# 71   7.47
# 128  7.93
# 176  6.29
# 131  6.37
# 53   6.47

# %%
y_test
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# 85     1.48
# 10     1.86
# 54     3.09
# 115    4.21
# 35     2.87
# 12     3.65
# 92     4.00
# 13     2.89
# 126    2.60
# 174    2.99
# 2      3.25
# 44     1.86
# 3      3.67
# 113    2.37
# 14     3.42
# 23     2.48
# 25     3.65
# 6      2.60
# 134    2.83
# 165    4.08
# 173    2.56
# 45     3.58
# 65     3.81
# 48     4.09
# 122    2.01
# 178    3.63
# 64     2.92
# 9      3.51
# 57     1.94
# 78     2.21
# 71     3.34
# 128    3.34
# 176    3.23
# 131    2.01
# 53     2.61
# Name: package, dtype: float64

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.89111601])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
plt.show()

# %% [markdown]
# # **Matrics**

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv('placement (1).csv')
df.head(7)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57
# 5  7.89     2.99
# 6  6.73     2.60

# %%
df.head()
df.shape
# Out:
# (200, 2)

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
#importing the metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([3.89111601, 3.09324469, 2.38464568, 2.57434935, 1.6537286 ,
#        1.77647803, 2.07219258, 2.93143862, 3.76278706, 2.93701814,
#        4.09197872, 3.51170867, 2.97049525, 2.40138424, 3.18809652,
#        3.46707251, 1.94386362, 3.24389172, 2.97607477, 3.41685683,
#        2.55761079, 3.16577844, 2.85890486, 3.12114229, 3.68467378,
#        2.8700639 , 3.49497011, 3.34432308, 3.91901361, 1.96060218,
#        3.65119666, 3.2104146 , 3.74046898, 2.7863711 , 2.78079158,
#        3.27178932, 3.52844723, 2.61340599, 2.65804215, 2.71383735])

# %%
y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# MAE 0.2884710931878175

# %%
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 0.12129235313495527

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 0.34827051717731616

# %%
print("MSE",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# MSE 0.780730147510384

# %%
# Adjusted R2 score
X_test.shape
# Out:
# (40, 1)

# %%
1 - ((1-r2)*(40-1)/(40-1-1)) # adjusted R2
# Out:
# 0.7749598882343415

# %%
#creaing another table to add a random Column
new_df1 = df.copy()
new_df1['random_feature'] = np.random.random(200)

new_df1 = new_df1[['cgpa','random_feature','package']]
new_df1.head()
# Out:
#    cgpa  random_feature  package
# 0  6.89        0.940514     3.26
# 1  5.12        0.368341     1.98
# 2  7.82        0.800431     3.25
# 3  7.42        0.403388     3.67
# 4  6.94        0.052971     3.57

# %%
plt.scatter(new_df1['random_feature'],new_df1['package'])
plt.xlabel('random_feature')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
X = new_df1.iloc[:,0:2]
y = new_df1.iloc[:,-1]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("R2 score",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# R2 score 0.7807795116539823

# %%
1 - ((1-r2)*(40-1)/(40-1-2))
# Out:
# 0.7689297555271705

# %%
# Another Dataframe to check a relevant column
new_df2 = df.copy()

new_df2['iq'] = new_df2['package'] + (np.random.randint(-12,12,200)/10)

new_df2 = new_df2[['cgpa','iq','package']]
new_df2.sample(5)
# Out:
#      cgpa    iq  package
# 193  4.57  2.54     1.94
# 60   5.61  1.79     2.19
# 8    6.09  2.21     2.31
# 94   5.83  3.02     2.42
# 123  5.10  2.30     2.30

# %%
plt.scatter(new_df2['iq'],new_df2['package'])
plt.xlabel('iq')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
np.random.randint(-100,100)
# Out:
# 4

# %%
X = new_df2.iloc[:,0:2]
y = new_df2.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)

# %%
print("R2 score",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# R2 score 0.7901924946086554

# %%
#Adjusted R2 score
1 - ((1-r2)*(40-1)/(40-1-2))
# Out:
# 0.7788515483712855
